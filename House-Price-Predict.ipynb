# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, FunctionTransformer, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, root_mean_squared_error
from datetime import datetime

# %%
df = pd.read_csv('uk_real_estate.csv')

df.head()
# Out:
#     Price  Bedrooms  Bathrooms  SqFt        City Postcode  Year_Built  \
# 0  310506         5          3  1136  Birmingham        B        1834
# 1  316926         1          1  2718  Manchester       SW        1983
# 2   65337         3          1  2882     Glasgow       SW        1899
# 3  206705         1          2  2660     Glasgow       SW        1971
# 4  634260         1          1  1475   Edinburgh        B        1978
#
#        Type  Garage  Lot_Area
# 0  Bungalow       0      4067
# 1     House       1      3601
# 2  Bungalow       0      3693
# 3     House       1      2540
# 4     House       0      1582

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Price       5000 non-null   int64
#  1   Bedrooms    5000 non-null   int64
#  2   Bathrooms   5000 non-null   int64
#  3   SqFt        5000 non-null   int64
#  4   City        5000 non-null   object
#  5   Postcode    5000 non-null   object
#  6   Year_Built  5000 non-null   int64
#  7   Type        5000 non-null   object
#  8   Garage      5000 non-null   int64
#  9   Lot_Area    5000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 390.8+ KB

# %%
df.describe()
# Out:
#                Price     Bedrooms    Bathrooms         SqFt   Year_Built  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   517988.859600     3.029200     1.998200  1730.879000  1911.690000
# std    271061.387684     1.402976     0.817759   722.729818    64.294739
# min     50148.000000     1.000000     1.000000   500.000000  1800.000000
# 25%    278808.750000     2.000000     1.000000  1103.750000  1855.750000
# 50%    520051.500000     3.000000     2.000000  1715.500000  1912.000000
# 75%    749902.500000     4.000000     3.000000  2352.000000  1967.000000
# max    999981.000000     5.000000     3.000000  2998.000000  2022.000000
#
#            Garage     Lot_Area
# count  5000.00000  5000.000000
# mean      0.50000  2761.597200
# std       0.50005  1308.415414
# min       0.00000   500.000000
# 25%       0.00000  1617.750000
# 50%       0.50000  2746.000000
# 75%       1.00000  3893.500000
# max       1.00000  4999.000000

# %%
df['Total_rooms'] = df['Bedrooms'] + df['Bathrooms']

# %%
df.head()
# Out:
#     Price  Bedrooms  Bathrooms  SqFt        City Postcode  Year_Built  \
# 0  310506         5          3  1136  Birmingham        B        1834
# 1  316926         1          1  2718  Manchester       SW        1983
# 2   65337         3          1  2882     Glasgow       SW        1899
# 3  206705         1          2  2660     Glasgow       SW        1971
# 4  634260         1          1  1475   Edinburgh        B        1978
#
#        Type  Garage  Lot_Area  Total_rooms
# 0  Bungalow       0      4067            8
# 1     House       1      3601            2
# 2  Bungalow       0      3693            4
# 3     House       1      2540            3
# 4     House       0      1582            2

# %%
df = df.drop(['Bedrooms', 'Bathrooms', 'City', 'Postcode'], axis = 1)

# %%
df.sample(5)
# Out:
#        Price  SqFt  Year_Built   Type  Garage  Lot_Area  Total_rooms
# 4161  241779  1250        1821  House       0      3810            4
# 45    195053  2682        1988  House       1      4705            7
# 1435  152724  2532        1802   Flat       0      3183            3
# 1206  924206  1070        1832  House       1      3088            5
# 399   567549  1351        2022   Flat       1      1995            3

# %%
X = df.iloc[:, 1:]
Y = df.iloc[:, 0]

# %%
class FeatureEngineer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()

        current_year = datetime.now().year
        X['House_Age'] = current_year - X['Year_Built']
        X['Lot_per_SqFt'] = X['Lot_Area'] / X['SqFt']

        return X[["House_Age", "Lot_per_SqFt", "Type", "Garage", "Total_rooms"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
X_train = pd.DataFrame(X_train, columns=X_train.columns)

# %%
df.columns
# Out:
# Index(['Price', 'SqFt', 'Year_Built', 'Type', 'Garage', 'Lot_Area',
#        'Total_rooms'],
#       dtype='object')

# %%
num_feature = ["House_Age", "Lot_per_SqFt", "Garage", "Total_rooms"]
cat_feature = ["Type"]

preprocessor = ColumnTransformer([
    ("log", FunctionTransformer(np.log1p), num_feature),
    ("cat", OneHotEncoder(handle_unknown='ignore'), cat_feature)
])

pipeline = Pipeline([
    ("feature", FeatureEngineer()),
    ("preprocess", preprocessor),
    ("model", RandomForestRegressor())
])

pipeline.fit(X_train, y_train)

y_pred = pipeline.predict(X_test)

print(mean_squared_error(y_pred, y_test))
print(root_mean_squared_error(y_pred, y_test))
# Out:
# 78737580471.77199
# 280602.1747452646

# %%
import pickle

file = 'houseprice.pkl'

with open(file, 'wb') as f:
    pickle.dump(pipeline, f)
